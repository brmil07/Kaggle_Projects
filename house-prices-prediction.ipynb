# %% [markdown]
# <a href="https://www.kaggle.com/code/brmil07/house-prices-prediction?scriptVersionId=160868710" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **Housing Prices Prediction**
# ---
# ## **Description**
# ---
# This notebook aims to predict the housing prices based on the datased provided by "Housing Prices Competition for Kaggle Learn Users"
#
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
#
# More info: [Housing Prices Competition for Kaggle Learn Users](https://www.kaggle.com/competitions/home-data-for-ml-course)

# %%
import numpy as np 
import pandas as pd 

from scipy.stats import uniform, randint

from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

# Read the data
df_train = pd.read_csv('../input/home-data-for-ml-course/train.csv', index_col='Id')
df_test = pd.read_csv('../input/home-data-for-ml-course/test.csv', index_col='Id')
x_train = df_train
x_test = df_test

# Remove rows with missing target, separate target from predictors
x_train.dropna(axis=0, subset=['SalePrice'], inplace=True)
y_train = x_train.SalePrice
x_train.drop(['SalePrice'], axis=1, inplace=True)

# %% [markdown]
# # **Exploratory Data Analysis**
# ---

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     588 non-null    object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
# dtypes: float64(3), int64(33), object(43)
# memory usage: 912.5+ KB

# %%
x_train.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    472.980137    94.244521    46.660274      21.954110     3.409589
# std     213.804841   125.338794    66.256028      61.119149    29.317331
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     334.500000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    25.000000       0.000000     0.000000
# 75%     576.000000   168.000000    68.000000       0.000000     0.000000
# max    1418.000000   857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
# [8 rows x 36 columns]

# %%
x_train.shape
# Out:
# (1460, 79)

# %%
x_train.duplicated().sum()
# Out:
# 0

# %%
x_train.isna().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# Length: 79, dtype: int64

# %%
x_train.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# Length: 79, dtype: int64

# %%
columns_with_null = x_train.columns[x_train.isnull().any()]
print("Columns with null/missing values:")
print(columns_with_null)
# Out:
# Columns with null/missing values:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
missing_val_count_by_column = (x_train.isnull().sum())
column_list = missing_val_count_by_column[missing_val_count_by_column > 0]
print(column_list)
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
x_train.nunique()
# Out:
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
# Street              2
#                  ...
# MiscVal            21
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# Length: 79, dtype: int64

# %% [markdown]
# # **Data Pre-Processing**
# ---

# %%
# Break off validation set from training data
X_train_full, X_valid_full, y_train, y_valid = train_test_split(x_train, y_train, 
                                                                train_size=0.8, test_size=0.2,
                                                                random_state=0)

# "Cardinality" means the number of unique values in a column
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
categorical_cols = [cname for cname in X_train_full.columns if
                    X_train_full[cname].nunique() < 10 and 
                    X_train_full[cname].dtype == "object"]

# Select numerical columns
numerical_cols = [cname for cname in X_train_full.columns if 
                X_train_full[cname].dtype in ['int64', 'float64']]

# Keep selected columns only
my_cols = categorical_cols + numerical_cols
X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()
X_test = x_test[my_cols].copy()

# %%
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# %% [markdown]
# # **Create a Pipeline**
# ---

# %%
# Define model
model = RandomForestRegressor(n_estimators=1000, random_state=0)

# Bundle preprocessing and modeling code in a pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', model)
                     ])

# Preprocessing of training data, fit model
clf.fit(X_train, y_train)

# Preprocessing of validation data, get predictions
preds = clf.predict(X_valid)

mae = mean_absolute_error(y_valid, preds)
mse = mean_squared_error(y_valid, preds)
r2_percentage = r2_score(y_valid, preds) * 100

print('MAE:', mae)
print('MSE:', mse)
print('R-squared (%):', r2_percentage)
# Out:
# MAE: 17277.429907534246
# MSE: 1103939079.217621
# R-squared (%): 84.01443580483424

# %% [markdown]
# # **Explore other Classification Models**
# ---

# %%
# Create a list of available models
models = [
    RandomForestRegressor(n_estimators=100, random_state=0),
    AdaBoostRegressor(n_estimators=50, learning_rate=0.1),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3),
    LinearRegression(),
    XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3),
    LGBMRegressor(n_estimators=100, learning_rate=0.1, max_depth=3),
    SVR(kernel='rbf', C=1.0, epsilon=0.1),
    KNeighborsRegressor(n_neighbors=5),
    Ridge(alpha=1.0),
    Lasso(alpha=1.0),
    DecisionTreeRegressor(max_depth=3),
    CatBoostRegressor(iterations=100, verbose=False)
]

model_name = ['RandomForestRegressor',
              'AdaBoostRegressor',
              'GradientBoostingRegressor', 
              'LinearRegression',
              'XGBRegressor',
              'LGBMRegressor', 
              'SVR',
              'KNeighborsRegressor', 
              'Ridge', 
              'Lasso',
              'DecisionTreeRegressor', 
              'CatBoostRegressor']

# Create a DataFrame to store results
results_df = pd.DataFrame(columns=['Model', 'MAE'])

# %%
# Loop through each model
for model, name in zip(models, model_name):
    # Bundle preprocessing and modeling code in a pipeline
    clf = Pipeline(steps=[('preprocessor', preprocessor),
                          ('model', model)])

    # Preprocessing of training data, fit model
    clf.fit(X_train, y_train)

    # Preprocessing of validation data, get predictions
    preds = clf.predict(X_valid)

    # Calculate MAE
    mae = mean_absolute_error(y_valid, preds)

    # Append results to DataFrame
    results_df = results_df._append({'Model': name, 'MAE': mae}, ignore_index=True)

# %%
results_df['Rank'] = results_df['MAE'].rank(ascending=True, method='first').astype(int)
results_df = results_df.sort_values(by='Rank')

# %%
results_df
# Out:
#                         Model           MAE  Rank
# 4                XGBRegressor  17054.506047     1
# 2   GradientBoostingRegressor  17078.255782     2
# 0       RandomForestRegressor  17614.819932     3
# 5               LGBMRegressor  17712.899045     4
# 11          CatBoostRegressor  18070.031077     5
# 8                       Ridge  22419.783962     6
# 9                       Lasso  23158.433350     7
# 3            LinearRegression  24072.482760     8
# 1           AdaBoostRegressor  25861.454780     9
# 7         KNeighborsRegressor  30342.865753    10
# 10      DecisionTreeRegressor  31448.278375    11
# 6                         SVR  55543.091171    12

# %%
# Perform cross-validation on the training data
cv_scores = cross_val_score(clf, X_train, y_train, cv=5, scoring='neg_mean_absolute_error')

# Display cross-validated scores
print('Cross-validated MAE scores:', -cv_scores)
print('Mean Cross-validated MAE:', -cv_scores.mean())
# Out:
# Cross-validated MAE scores: [14604.28308559 18564.68866041 17217.29945068 17327.8868361
#  13499.00035437]
# Mean Cross-validated MAE: 16242.631677426738

# %% [markdown]
# # **Improve the Performance of the Model**
# ---

# %%
# Find the best model object based on its name
best_model_index = model_name.index(results_df.iloc[0]['Model'])
best_model = models[best_model_index]

print(f"Best Model: {best_model}")
# Out:
# Best Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Define the parameter grid to search
param_dist = {'model__n_estimators': randint(50, 500),
              'model__learning_rate': uniform(0.01, 0.3),
              'model__max_depth': randint(3, 10),
              'model__min_samples_split': randint(2, 20),
              'model__min_samples_leaf': randint(1, 10),
              'model__subsample': uniform(0.6, 0.4)  # Adjust the range based on your preference
              # Add other hyperparameters to tune
             }

# %%
# Create a pipeline with the best model
best_model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ('model', best_model)])

# Perform RandomizedSearchCV for hyperparameter tuning
random_search = RandomizedSearchCV(best_model_pipeline, 
                                   param_distributions=param_dist,
                                   n_iter=50, 
                                   cv=5, 
                                   scoring='neg_mean_absolute_error', 
                                   n_jobs=-1, 
                                   random_state=0)
random_search.fit(X_train, y_train)

# Get the best model from the grid search
best_model_tuned = random_search.best_estimator_
# Out:
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:32] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:35] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:43] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:46] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:17:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:22] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:25] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:52] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:18:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:12] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:19] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:24] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:37] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:39] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:41] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:19:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:19] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:21] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:23] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:26] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:32] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:35] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:37] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:39] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:41] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:43] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:44] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:46] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:48] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:52] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:52] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:52] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:20:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:11] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:12] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:12] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:13] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:15] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:18] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:22] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:25] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:29] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:34] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:37] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:41] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:21:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:08] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:11] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:12] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:13] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:15] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:18] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:19] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:21] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:21] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:22] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:23] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:23] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:24] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:25] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:25] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:26] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:27] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:29] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:32] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:34] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:36] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:37] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:39] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:39] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:41] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:22:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:12] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:15] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:15] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:19] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:21] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:23] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:27] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:34] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:43] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:44] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:44] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:23:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:08] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:08] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [13:24:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Print the best hyperparameters
print("Best Hyperparameters:", random_search.best_params_)
# Out:
# Best Hyperparameters: {'model__learning_rate': 0.061488903178432155, 'model__max_depth': 5, 'model__min_samples_leaf': 9, 'model__min_samples_split': 3, 'model__n_estimators': 183, 'model__subsample': 0.67999860995856}

# %% [markdown]
# # **Create a Prediction for Test Dataset**
# ---

# %%
# Get predictions using the best model
preds_test = best_model_pipeline.predict(X_test)

# %%
# Use the best model to predict the test data
preds_test_tuned = best_model_tuned.predict(X_test)

# %%
# Save test predictions to file
output = pd.DataFrame({'Id': X_test.index,'SalePrice': preds_test_tuned})
output
# Out:
#         Id      SalePrice
# 0     1461  125882.734375
# 1     1462  156989.437500
# 2     1463  182619.453125
# 3     1464  189738.156250
# 4     1465  180433.531250
# ...    ...            ...
# 1454  2915   82694.164062
# 1455  2916   86052.976562
# 1456  2917  170146.046875
# 1457  2918  114033.429688
# 1458  2919  222801.281250
#
# [1459 rows x 2 columns]

# %%
output.to_csv('submission.csv', index=False)
