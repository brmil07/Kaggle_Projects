# %% [markdown]
# <a href="https://www.kaggle.com/code/brmil07/house-prices-prediction?scriptVersionId=161013317" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **Housing Prices Prediction**
# ---
# ## **Description**
# ---
# This notebook aims to predict the housing prices based on the datased provided by "Housing Prices Competition for Kaggle Learn Users"
#
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
#
# More info: [Housing Prices Competition for Kaggle Learn Users](https://www.kaggle.com/competitions/home-data-for-ml-course)

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns

from math import ceil
from tqdm import tqdm
from scipy.stats import uniform, randint

from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

# Read the data
df_train = pd.read_csv('../input/home-data-for-ml-course/train.csv', index_col='Id')
df_test = pd.read_csv('../input/home-data-for-ml-course/test.csv', index_col='Id')
x_train = df_train
x_test = df_test

# Remove rows with missing target, separate target from predictors
x_train.dropna(axis=0, subset=['SalePrice'], inplace=True)
y_train = x_train.SalePrice
x_train.drop(['SalePrice'], axis=1, inplace=True)

# %% [markdown]
# # **Exploratory Data Analysis**
# ---

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     588 non-null    object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
# dtypes: float64(3), int64(33), object(43)
# memory usage: 912.5+ KB

# %%
x_train.describe().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_ddf87_row0_col0, #T_ddf87_row0_col1, #T_ddf87_row0_col3, #T_ddf87_row0_col4, #T_ddf87_row0_col14, #T_ddf87_row0_col16, #T_ddf87_row0_col17, #T_ddf87_row0_col18, #T_ddf87_row0_col19, #T_ddf87_row0_col20, #T_ddf87_row0_col21, #T_ddf87_row0_col22, #T_ddf87_row0_col23, #T_ddf87_row0_col25, #T_ddf87_row0_col26, #T_ddf87_row0_col27, #T_ddf87_row0_col28, #T_ddf87_row0_col29, #T_ddf87_row0_col30, #T_ddf87_row0_col31, #T_ddf87_row0_col32, #T_ddf87_row0_col34, #T_ddf87_row1_col35, #T_ddf87_row3_col35, #T_ddf87_row4_col35, #T_ddf87_row5_col35, #T_ddf87_row6_col6, #T_ddf87_row6_col35, #T_ddf87_row7_col2, #T_ddf87_row7_col5, #T_ddf87_row7_col6, #T_ddf87_row7_col7, #T_ddf87_row7_col8, #T_ddf87_row7_col9, #T_ddf87_row7_col10, #T_ddf87_row7_col11, #T_ddf87_row7_col12, #T_ddf87_row7_col13, #T_ddf87_row7_col15, #T_ddf87_row7_col24, #T_ddf87_row7_col33, #T_ddf87_row7_col35 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_ddf87_row0_col2, #T_ddf87_row1_col3, #T_ddf87_row1_col4, #T_ddf87_row1_col16, #T_ddf87_row1_col17, #T_ddf87_row1_col18, #T_ddf87_row1_col19, #T_ddf87_row1_col20, #T_ddf87_row1_col21, #T_ddf87_row1_col22, #T_ddf87_row1_col23, #T_ddf87_row1_col25, #T_ddf87_row1_col30, #T_ddf87_row1_col32, #T_ddf87_row1_col33, #T_ddf87_row1_col34, #T_ddf87_row2_col1, #T_ddf87_row2_col3, #T_ddf87_row2_col4, #T_ddf87_row2_col5, #T_ddf87_row2_col6, #T_ddf87_row2_col16, #T_ddf87_row2_col17, #T_ddf87_row2_col18, #T_ddf87_row2_col19, #T_ddf87_row2_col20, #T_ddf87_row2_col21, #T_ddf87_row2_col22, #T_ddf87_row2_col23, #T_ddf87_row2_col24, #T_ddf87_row2_col25, #T_ddf87_row2_col34, #T_ddf87_row2_col35, #T_ddf87_row3_col0, #T_ddf87_row3_col1, #T_ddf87_row3_col2, #T_ddf87_row3_col3, #T_ddf87_row3_col4, #T_ddf87_row3_col7, #T_ddf87_row3_col8, #T_ddf87_row3_col9, #T_ddf87_row3_col10, #T_ddf87_row3_col11, #T_ddf87_row3_col12, #T_ddf87_row3_col13, #T_ddf87_row3_col14, #T_ddf87_row3_col15, #T_ddf87_row3_col16, #T_ddf87_row3_col17, #T_ddf87_row3_col18, #T_ddf87_row3_col19, #T_ddf87_row3_col20, #T_ddf87_row3_col21, #T_ddf87_row3_col22, #T_ddf87_row3_col23, #T_ddf87_row3_col25, #T_ddf87_row3_col26, #T_ddf87_row3_col27, #T_ddf87_row3_col28, #T_ddf87_row3_col29, #T_ddf87_row3_col30, #T_ddf87_row3_col31, #T_ddf87_row3_col32, #T_ddf87_row3_col33, #T_ddf87_row3_col34, #T_ddf87_row4_col0, #T_ddf87_row4_col3, #T_ddf87_row4_col4, #T_ddf87_row4_col7, #T_ddf87_row4_col8, #T_ddf87_row4_col9, #T_ddf87_row4_col13, #T_ddf87_row4_col14, #T_ddf87_row4_col16, #T_ddf87_row4_col17, #T_ddf87_row4_col18, #T_ddf87_row4_col19, #T_ddf87_row4_col20, #T_ddf87_row4_col21, #T_ddf87_row4_col22, #T_ddf87_row4_col23, #T_ddf87_row4_col25, #T_ddf87_row4_col27, #T_ddf87_row4_col28, #T_ddf87_row4_col29, #T_ddf87_row4_col30, #T_ddf87_row4_col31, #T_ddf87_row4_col32, #T_ddf87_row4_col33, #T_ddf87_row4_col34, #T_ddf87_row5_col3, #T_ddf87_row5_col4, #T_ddf87_row5_col7, #T_ddf87_row5_col9, #T_ddf87_row5_col13, #T_ddf87_row5_col14, #T_ddf87_row5_col16, #T_ddf87_row5_col17, #T_ddf87_row5_col18, #T_ddf87_row5_col19, #T_ddf87_row5_col20, #T_ddf87_row5_col21, #T_ddf87_row5_col22, #T_ddf87_row5_col23, #T_ddf87_row5_col25, #T_ddf87_row5_col27, #T_ddf87_row5_col29, #T_ddf87_row5_col30, #T_ddf87_row5_col31, #T_ddf87_row5_col32, #T_ddf87_row5_col33, #T_ddf87_row5_col34, #T_ddf87_row6_col4, #T_ddf87_row6_col9, #T_ddf87_row6_col14, #T_ddf87_row6_col16, #T_ddf87_row6_col17, #T_ddf87_row6_col18, #T_ddf87_row6_col19, #T_ddf87_row6_col20, #T_ddf87_row6_col21, #T_ddf87_row6_col22, #T_ddf87_row6_col23, #T_ddf87_row6_col25, #T_ddf87_row6_col29, #T_ddf87_row6_col30, #T_ddf87_row6_col31, #T_ddf87_row6_col32, #T_ddf87_row6_col33, #T_ddf87_row7_col16, #T_ddf87_row7_col17, #T_ddf87_row7_col18, #T_ddf87_row7_col19, #T_ddf87_row7_col21, #T_ddf87_row7_col23, #T_ddf87_row7_col25 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_ddf87_row0_col5 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_ddf87_row0_col6, #T_ddf87_row0_col35 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_ddf87_row0_col7 {
#   background-color: #c2df23;
#   color: #000000;
# }
# #T_ddf87_row0_col8, #T_ddf87_row0_col12 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_ddf87_row0_col9, #T_ddf87_row5_col6 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_ddf87_row0_col10 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_ddf87_row0_col11 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_ddf87_row0_col13 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_ddf87_row0_col15, #T_ddf87_row2_col13, #T_ddf87_row5_col15, #T_ddf87_row6_col11 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_ddf87_row0_col24 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
# }
# #T_ddf87_row0_col33, #T_ddf87_row4_col10 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col0 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col1, #T_ddf87_row2_col2, #T_ddf87_row2_col29, #T_ddf87_row5_col1 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col2, #T_ddf87_row2_col28, #T_ddf87_row6_col28 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col5, #T_ddf87_row4_col6 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_ddf87_row1_col6, #T_ddf87_row5_col24 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_ddf87_row1_col7, #T_ddf87_row1_col27 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col8, #T_ddf87_row2_col8 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col9, #T_ddf87_row1_col28, #T_ddf87_row2_col14, #T_ddf87_row2_col33, #T_ddf87_row4_col1, #T_ddf87_row6_col0 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col10, #T_ddf87_row6_col12 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col11, #T_ddf87_row5_col12 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col12, #T_ddf87_row2_col10 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col13 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col14, #T_ddf87_row6_col3, #T_ddf87_row6_col34, #T_ddf87_row7_col3, #T_ddf87_row7_col4, #T_ddf87_row7_col20, #T_ddf87_row7_col34 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col15 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col24, #T_ddf87_row5_col5 {
#   background-color: #f4e61e;
#   color: #000000;
# }
# #T_ddf87_row1_col26 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col29, #T_ddf87_row2_col0, #T_ddf87_row2_col12 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_ddf87_row1_col31, #T_ddf87_row7_col22 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_ddf87_row2_col7, #T_ddf87_row2_col9 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_ddf87_row2_col11 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_ddf87_row2_col15, #T_ddf87_row2_col31, #T_ddf87_row5_col2 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_ddf87_row2_col26 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_ddf87_row2_col27 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_ddf87_row2_col30, #T_ddf87_row5_col0 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_ddf87_row2_col32, #T_ddf87_row4_col2 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_ddf87_row3_col5 {
#   background-color: #d2e21b;
#   color: #000000;
# }
# #T_ddf87_row3_col6, #T_ddf87_row4_col5, #T_ddf87_row7_col26 {
#   background-color: #ece51b;
#   color: #000000;
# }
# #T_ddf87_row3_col24 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_ddf87_row4_col11 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_ddf87_row4_col12, #T_ddf87_row6_col8 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_ddf87_row4_col15 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_ddf87_row4_col24 {
#   background-color: #efe51c;
#   color: #000000;
# }
# #T_ddf87_row4_col26 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_ddf87_row5_col8 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_ddf87_row5_col10 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_ddf87_row5_col11 {
#   background-color: #453882;
#   color: #f1f

# %%
x_train.shape
# Out:
# (1460, 79)

# %%
x_train.duplicated().sum()
# Out:
# 0

# %%
x_train.isna().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# Length: 79, dtype: int64

# %%
x_train.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# Length: 79, dtype: int64

# %%
columns_with_null = x_train.columns[x_train.isnull().any()]
print("Columns with null/missing values:")
print(columns_with_null)
# Out:
# Columns with null/missing values:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
missing_val_count_by_column = (x_train.isnull().sum())
column_list = missing_val_count_by_column[missing_val_count_by_column > 0]
print(column_list)
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
x_train.nunique()
# Out:
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
# Street              2
#                  ...
# MiscVal            21
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# Length: 79, dtype: int64

# %% [markdown]
# # **Data Pre-Processing**
# ---

# %%
# Break off validation set from training data
X_train_full, X_valid_full, y_train, y_valid = train_test_split(x_train, y_train, 
                                                                train_size=0.8, test_size=0.2,
                                                                random_state=0)

# "Cardinality" means the number of unique values in a column
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
categorical_cols = [cname for cname in X_train_full.columns if
                    X_train_full[cname].nunique() < 10 and 
                    X_train_full[cname].dtype == "object"]

# Select numerical columns
numerical_cols = [cname for cname in X_train_full.columns if 
                X_train_full[cname].dtype in ['int64', 'float64']]

# Keep selected columns only
my_cols = categorical_cols + numerical_cols
X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()
X_test = x_test[my_cols].copy()

# %%
# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# %% [markdown]
# # **Create a Pipeline**
# ---

# %%
# Define model
model = RandomForestRegressor(n_estimators=1000, random_state=0)

# Bundle preprocessing and modeling code in a pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', model)
                     ])

# Preprocessing of training data, fit model
clf.fit(X_train, y_train)

# Preprocessing of validation data, get predictions
preds = clf.predict(X_valid)

mae = mean_absolute_error(y_valid, preds)
mse = mean_squared_error(y_valid, preds)
r2_percentage = r2_score(y_valid, preds) * 100

print('MAE:', mae)
print('MSE:', mse)
print('R-squared (%):', r2_percentage)
# Out:
# MAE: 17277.429907534246
# MSE: 1103939079.217621
# R-squared (%): 84.01443580483424

# %% [markdown]
# # **Explore other Classification Models**
# ---

# %%
# Create a list of available models
models = [
    RandomForestRegressor(n_estimators=100, random_state=0),
    AdaBoostRegressor(n_estimators=50, learning_rate=0.1),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3),
    LinearRegression(),
    XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3),
    LGBMRegressor(n_estimators=100, learning_rate=0.1, max_depth=3),
    SVR(kernel='rbf', C=1.0, epsilon=0.1),
    KNeighborsRegressor(n_neighbors=5),
    Ridge(alpha=1.0),
    Lasso(alpha=1.0),
    DecisionTreeRegressor(max_depth=3),
    CatBoostRegressor(iterations=100, verbose=False)
]

model_name = ['RandomForestRegressor',
              'AdaBoostRegressor',
              'GradientBoostingRegressor', 
              'LinearRegression',
              'XGBRegressor',
              'LGBMRegressor', 
              'SVR',
              'KNeighborsRegressor', 
              'Ridge', 
              'Lasso',
              'DecisionTreeRegressor', 
              'CatBoostRegressor']

# Create a DataFrame to store results
results_df = pd.DataFrame(columns=['Model', 'MAE'])

# %%
# Loop through each model
for model, name in tqdm(zip(models, model_name), total=len(models), desc="Training Models"):
    # Bundle preprocessing and modeling code in a pipeline
    clf = Pipeline(steps=[('preprocessor', preprocessor),
                          ('model', model)])

    # Preprocessing of training data, fit model
    clf.fit(X_train, y_train)

    # Preprocessing of validation data, get predictions
    preds = clf.predict(X_valid)

    # Calculate MAE
    mae = mean_absolute_error(y_valid, preds)

    # Append results to DataFrame
    results_df = results_df._append({'Model': name, 'MAE': mae}, ignore_index=True)
# Out:
# Training Models: 100%|██████████| 12/12 [00:07<00:00,  1.65it/s]

# %%
results_df['Rank'] = results_df['MAE'].rank(ascending=True, method='first').astype(int)
results_df = results_df.sort_values(by='Rank')
results_df.style.background_gradient(cmap='cividis')
# Out:
# <style type="text/css">
# #T_fad83_row0_col1, #T_fad83_row0_col2, #T_fad83_row1_col1 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_fad83_row1_col2 {
#   background-color: #013271;
#   color: #f1f1f1;
# }
# #T_fad83_row2_col1 {
#   background-color: #002553;
#   color: #f1f1f1;
# }
# #T_fad83_row2_col2, #T_fad83_row7_col1 {
#   background-color: #2f426d;
#   color: #f1f1f1;
# }
# #T_fad83_row3_col1 {
#   background-color: #002554;
#   color: #f1f1f1;
# }
# #T_fad83_row3_col2 {
#   background-color: #48526c;
#   color: #f1f1f1;
# }
# #T_fad83_row4_col1 {
#   background-color: #002758;
#   color: #f1f1f1;
# }
# #T_fad83_row4_col2 {
#   background-color: #5e636f;
#   color: #f1f1f1;
# }
# #T_fad83_row5_col1 {
#   background-color: #203a6f;
#   color: #f1f1f1;
# }
# #T_fad83_row5_col2 {
#   background-color: #727374;
#   color: #f1f1f1;
# }
# #T_fad83_row6_col1 {
#   background-color: #273e6e;
#   color: #f1f1f1;
# }
# #T_fad83_row6_col2 {
#   background-color: #878478;
#   color: #f1f1f1;
# }
# #T_fad83_row7_col2 {
#   background-color: #9d9576;
#   color: #f1f1f1;
# }
# #T_fad83_row8_col1 {
#   background-color: #414d6c;
#   color: #f1f1f1;
# }
# #T_fad83_row8_col2 {
#   background-color: #b6a96f;
#   color: #f1f1f1;
# }
# #T_fad83_row9_col1 {
#   background-color: #5a5f6e;
#   color: #f1f1f1;
# }
# #T_fad83_row9_col2 {
#   background-color: #cebc63;
#   color: #000000;
# }
# #T_fad83_row10_col1 {
#   background-color: #60646f;
#   color: #f1f1f1;
# }
# #T_fad83_row10_col2 {
#   background-color: #e7d150;
#   color: #000000;
# }
# #T_fad83_row11_col1, #T_fad83_row11_col2 {
#   background-color: #fee838;
#   color: #000000;
# }
# </style>
# <table id="T_fad83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fad83_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fad83_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fad83_level0_col2" class="col_heading level0 col2" >Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fad83_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_fad83_row0_col0" class="data row0 col0" >GradientBoostingRegressor</td>
#       <td id="T_fad83_row0_col1" class="data row0 col1" >17024.422245</td>
#       <td id="T_fad83_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_fad83_row1_col0" class="data row1 col0" >XGBRegressor</td>
#       <td id="T_fad83_row1_col1" class="data row1 col1" >17054.506047</td>
#       <td id="T_fad83_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_fad83_row2_col0" class="data row2 col0" >RandomForestRegressor</td>
#       <td id="T_fad83_row2_col1" class="data row2 col1" >17614.819932</td>
#       <td id="T_fad83_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_fad83_row3_col0" class="data row3 col0" >LGBMRegressor</td>
#       <td id="T_fad83_row3_col1" class="data row3 col1" >17712.899045</td>
#       <td id="T_fad83_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row4" class="row_heading level0 row4" >11</th>
#       <td id="T_fad83_row4_col0" class="data row4 col0" >CatBoostRegressor</td>
#       <td id="T_fad83_row4_col1" class="data row4 col1" >18070.031077</td>
#       <td id="T_fad83_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_fad83_row5_col0" class="data row5 col0" >Ridge</td>
#       <td id="T_fad83_row5_col1" class="data row5 col1" >22419.783962</td>
#       <td id="T_fad83_row5_col2" class="data row5 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_fad83_row6_col0" class="data row6 col0" >Lasso</td>
#       <td id="T_fad83_row6_col1" class="data row6 col1" >23158.433350</td>
#       <td id="T_fad83_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_fad83_row7_col0" class="data row7 col0" >LinearRegression</td>
#       <td id="T_fad83_row7_col1" class="data row7 col1" >24072.482760</td>
#       <td id="T_fad83_row7_col2" class="data row7 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_fad83_row8_col0" class="data row8 col0" >AdaBoostRegressor</td>
#       <td id="T_fad83_row8_col1" class="data row8 col1" >26469.840090</td>
#       <td id="T_fad83_row8_col2" class="data row8 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_fad83_row9_col0" class="data row9 col0" >KNeighborsRegressor</td>
#       <td id="T_fad83_row9_col1" class="data row9 col1" >30342.865753</td>
#       <td id="T_fad83_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fad83_row10_col0" class="data row10 col0" >DecisionTreeRegressor</td>
#       <td id="T_fad83_row10_col1" class="data row10 col1" >31448.278375</td>
#       <td id="T_fad83_row10_col2" class="data row10 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_fad83_level0_row11" class="row_heading level0 row11" >6</th>
#       <td id="T_fad83_row11_col0" class="data row11 col0" >SVR</td>
#       <td id="T_fad83_row11_col1" class="data row11 col1" >55543.091171</td>
#       <td id="T_fad83_row11_col2" class="data row11 col2" >12</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Perform cross-validation on the training data
cv_scores = cross_val_score(clf, X_train, y_train, cv=5, scoring='neg_mean_absolute_error')

# Display cross-validated scores
print('Cross-validated MAE scores:', -cv_scores)
print('Mean Cross-validated MAE:', -cv_scores.mean())
# Out:
# Cross-validated MAE scores: [14604.28308559 18564.68866041 17217.29945068 17327.8868361
#  13499.00035437]
# Mean Cross-validated MAE: 16242.631677426738

# %% [markdown]
# # **Improve the Performance of the Model**
# ---

# %%
# Find the best model object based on its name
best_model_index = model_name.index(results_df.iloc[0]['Model'])
best_model = models[best_model_index]

print(f"Best Model: {best_model}")
# Out:
# Best Model: GradientBoostingRegressor()

# %%
# Define the parameter grid to search
param_dist = {'model__n_estimators': randint(50, 1000),
              'model__learning_rate': uniform(0.01, 0.5),
              'model__max_depth': randint(2, 20),
              'model__min_samples_split': randint(1, 10),
              'model__min_samples_leaf': randint(1, 10),
              'model__subsample': uniform(0.6, 0.4)
              # Add other hyperparameters to tune
             }

# %%
# Create a pipeline with the best model
best_model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ('model', best_model)])

# Perform RandomizedSearchCV for hyperparameter tuning
random_search = RandomizedSearchCV(best_model_pipeline, 
                                   param_distributions=param_dist,
                                   n_iter=50, 
                                   cv=20, 
                                   scoring='neg_mean_absolute_error', 
                                   n_jobs=-1, 
                                   random_state=0)
random_search.fit(X_train, y_train)

# Get the best model from the grid search
best_model_tuned = random_search.best_estimator_
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 180 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_gb.py", line 420, in fit
#     self._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of GradientBoostingRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [-17421.79026882 -18850.41099495 -17838.61714083 -21595.94200697
#  -21162.24961356             nan -20543.71518496             nan
#  -19558.49380946 -15959.78892494 -17333.89452143 -17864.20363555
#  -16654.44208023 -17177.01438954             nan             nan
#  -16183.51446322 -17726.5047105  -18897.955534               nan
#  -18285.67448365 -16442.07209593 -18461.27148234 -19048.95321623
#              nan -22747.17362664 -17499.25348835 -17773.10593153
#  -15942.47572091 -16867.00255851 -18863.88866821 -20608.51055499
#  -16906.69074117 -16680.7756039  -20209.1245352  -16422.93226439
#  -16716.68127918 -20983.21034024 -16152.2566208  -21062.87003904
#  -17280.08657052 -17193.96418568 -22042.43349308             nan
#  -16355.11351118 -17285.64765922             nan -17295.54063392
#              nan -18594.75204382]
#   warnings.warn(

# %%
# Print the best hyperparameters
print("Best Hyperparameters:", random_search.best_params_)
# Out:
# Best Hyperparameters: {'model__learning_rate': 0.0561869447304491, 'model__max_depth': 3, 'model__min_samples_leaf': 7, 'model__min_samples_split': 9, 'model__n_estimators': 431, 'model__subsample': 0.728398896549399}

# %% [markdown]
# # **Create a Prediction for Test Dataset**
# ---

# %%
# Get predictions using the best model
preds_test = best_model_pipeline.predict(X_test)

# %%
# Use the best model to predict the test data
preds_test_tuned = best_model_tuned.predict(X_test)

# %%
# Save test predictions to file
output = pd.DataFrame({'Id': X_test.index,'SalePrice': preds_test_tuned})
output
# Out:
#         Id      SalePrice
# 0     1461  119319.406624
# 1     1462  160257.780318
# 2     1463  182888.541359
# 3     1464  187022.555474
# 4     1465  199317.667575
# ...    ...            ...
# 1454  2915   80438.089277
# 1455  2916   84054.851867
# 1456  2917  174161.556180
# 1457  2918  124063.010828
# 1458  2919  236445.930693
#
# [1459 rows x 2 columns]

# %%
output.to_csv('submission.csv', index=False)
