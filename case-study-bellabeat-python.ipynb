# %% [markdown]
# <a href="https://www.kaggle.com/code/brmil07/case-study-bellabeat-python?scriptVersionId=162281737" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **🖼️Case Study: How Can a Wellness Technology Company Play It Smart?💡**
# ***
#
# ## **1. Scenario 📰**
# ---
# A junior data analyst working on the marketing analyst team at Bellabeat, a high-tech manufacturer of health-focused products for women. Bellabeat is a successful small company, but they have the potential to become a larger player in the global smart device market. Urška Sršen, co-founder and Chief Creative Officer of Bellabeat, believes that analyzing smart device fitness data could help unlock new growth opportunities for the company. The data analyst is asked to focus on one of Bellabeat’s products and analyze smart device data to gain insight into how consumers are using their smart devices. The insights discovered will then help guide the marketing strategy for the company. In the end, the analysis will be presented to the Bellabeat executive team along with your high-level recommendations for Bellabeat’s marketing strategy.
#
# ## **2. Company Profile 🧑🏻‍💼**
# ---
# ![image.png](attachment:a1dd20d1-a4a0-4af7-9d73-3492bc088e47.png)
#
# Urška Sršen and Sando Mur founded Bellabeat, a high-tech company that manufactures health-focused smart products. Sršen used her background as an artist to develop beautifully designed technology that informs and inspires women around the world. Collecting data on activity, sleep, stress, and reproductive health has allowed Bellabeat to empower women with knowledge about their own health and habits. Since it was founded in 2013, Bellabeat has grown rapidly and quickly positioned itself as a tech-driven wellness company for women.
#
# By 2016, Bellabeat had opened offices around the world and launched multiple products. Bellabeat products became available through a growing number of online retailers in addition to their own e-commerce channel on [the website](https://bellabeat.com/). The company has invested in traditional advertising media, such as radio, out-of-home billboards, print, and television, but focuses on digital marketing extensively. Bellabeat invests year-round in Google Search, maintaining active Facebook and Instagram pages, and consistently engages consumers on Twitter. Additionally, Bellabeat runs video ads on Youtube and display ads on the Google Display Network to support campaigns around key marketing dates.
#
# Sršen knows that an analysis of Bellabeat’s available consumer data would reveal more opportunities for growth. She has asked the marketing analytics team to focus on a Bellabeat product and analyze smart device usage data in order to gain insight into how people are already using their smart devices. Then, using this information, she would like high-level recommendations for how these trends can inform Bellabeat marketing strategy.
#
# ## **3. Company Product ⌚**
# ---
# * Bellabeat app: The Bellabeat app provides users with health data related to their activity, sleep, stress, menstrual cycle, and mindfulness habits. This data can help users better understand their current habits and make healthy decisions. The Bellabeat app connects to their line of smart wellness products.
# * Leaf: Bellabeat’s classic wellness tracker can be worn as a bracelet, necklace, or clip. The Leaf tracker connects to the Bellabeat app to track activity, sleep, and stress.
# * Time: This wellness watch combines the timeless look of a classic timepiece with smart technology to track user activity, sleep, and stress. The Time watch connects to the Bellabeat app to provide you with insights into your daily wellness.
# * Spring: This is a water bottle that tracks daily water intake using smart technology to ensure that you are appropriately hydrated throughout the day. The Spring bottle connects to the Bellabeat app to track your hydration levels.
# * Bellabeat membership: Bellabeat also offers a subscription-based membership program for users. Membership gives users 24/7 access to fully personalized guidance on nutrition, activity, sleep, health and beauty, and mindfulness based on their lifestyle and goals.
#
# ## **4. Data Preparation 📦**
# ---
# Sršen encourages you to use public data that explores smart device users’ daily habits. She points the junior data analyst to a specific data set.
#
# [FitBit Fitness Tracker Data](https://www.kaggle.com/datasets/arashnic/fitbit) (CC0: Public Domain, dataset made available through [Mobius](https://www.kaggle.com/arashnic)): This Kaggle data set contains personal fitness tracker from thirty fitbit users. Thirty eligible Fitbit users consented to the submission of personal tracker data, including minute-level output for physical activity, heart rate, and sleep monitoring. It includes information about daily activity, steps, and heart rate that can be used to explore users’ habits.
#
# Sršen tells the junior data analyst that this data set might have some limitations, and encourages to consider adding another data to help address those limitations as begin to work more with this data.

# %% [markdown]
# # **Ask Phase 💬**
# ***
#
# ## **1. Identify Business Task 🔬**
# ---
# Focus on one of Bellabeat’s products and analyze smart device data to gain insight into how consumers are using their smart devices. The discovered insights will then help guide marketing strategy for the company.
#
# These questions will guide the analysis:
# * What are some trends in smart device usage?
# * How could these trends apply to Bellabeat customers?
# * How could these trends help influence Bellabeat marketing strategy?
#
# ## **2. 👩🏻‍💼Key Stakeholders👨🏻‍💼**
# ---
# * Urška Sršen: Bellabeat’s cofounder and Chief Creative Officer.
# * Sando Mur: Mathematician and Bellabeat’s cofounder; key member of the Bellabeat executive team.
# * Bellabeat marketing analytics team: A team of data analysts responsible for collecting, analyzing, and reporting data that helps guide Bellabeat’s marketing strategy. You joined this team six months ago and have been busy learning about Bellabeat’’s mission and business goals — as well as how you, as a junior data analyst, can help Bellabeat achieve them.

# %% [markdown]
# # **Prepare Phase 🛠️**
# ***
#
# ## **1. The dataset**
# ---
# The FitBit Fitness Tracker Data which is a public data that explores smart device users’ daily habits is used. This dataset contains personal fitnes tracket from thirty fitbit users. Thirty eligible Fitbit users consented to the submission of personal tracker data, including minute-level output for physical activity, heart rate, and sleep monitoring. It includes information about daily activity, steps, and heart rate that can be used to explore users’ habits.
#
# The dataset can be downloaded by clicking this [link](https://www.kaggle.com/datasets/arashnic/fitbit).
#
# ## **2. Dataset information**
# ---
# This dataset generated by respondents to a distributed survey via Amazon Mechanical Turk between 03.12.2016-05.12.2016. Thirty eligible Fitbit users consented to the submission of personal tracker data, including minute-level output for physical activity, heart rate, and sleep monitoring. Individual reports can be parsed by export session ID (column A) or timestamp (column B). Variation between output represents use of different types of Fitbit trackers and individual tracking behaviors / preferences.
#
# ## **3. Data Organization**
# ---
# There are 18 CSV documents where each document represents different quantitative data tracked by Fitbit. The data is considered long since each row represent one data point per title. Hence, the title will have data in multiple rows. Every user has a unique ID and different rows since data is tracked by day and time.
#
# ## **4. Data privacy and accesibility**
# ---
# This dataset is open-source by looking up the metadata. The owner of this dataset Möbius has dedicated the work to the public domain under copyright law CC0. Everyone can download, edit, share and perform the work for certain purposes without the need for asking permission.
#
# ## **5. ROCCC**
# ---
# * Reliable: There low participation in this dataset which is 30 fitbit users.
# * Original: These datasets were generated by respondents to a distributed survey via Amazon Mechanical Turk.
# * Comprehensive: The dataset can be used for this case and the parameters match most of Bellabeat's products' parameters.
# * Current: These datasets were generated between 03.12.2016-05.12.2016.
# * Cited: The data was collected from a third party (Amazon Mechanical Turk). The link of the data source: [](https://zenodo.org/record/53894#.ZAiD4XbMJPa)
#
# ## **6. Data Integrity**
# ---
# Due to the limitation of size (30 users) and not having any demographic information we could encounter a sampling bias. We are not sure if the sample is representative of the population as a whole. These missing demographics could provide more insight for our results. Could older individuals use certain features more? Would individuals with higher income have more time to dedicate to working out? Where are our users located, rural areas, city areas? Bellabeat is a women-centric device, yet we have no indication of the data collected being from women. Another problem is that the dataset is not current and also the time limitation of the survey (2 months long).
#
# ## **7. Data selection**
# ---
# The following data is used in this case study:
# * dailyActivity_merged.csv

# %% [markdown]
# # **Process Phase 🏭**
# ***
#
# Python will be used in this case study for data preparation and processing.
#
# ## **1. Loading packages and preparing the environment 📥**
# ---
# Pandas and NumPy Python packages are used in this analysis for data manipulation.

# %%
#Importing packages and preparing the environment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **2. Importing Data 🗄️**
# ---
# Open the chosen dataset which format is in csv file using pandas library and put it into a dataframe.

# %%
DA_df = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv')

# %% [markdown]
# ## **3. Prepare Data 🖨️**
# ---
# Key Tasks:
# * Identify how it’s organized.
# * Sort and filter the data.
# * Determine the credibility of the data.

# %%
#Show the first 5 rows of the dataframe
DA_df.head().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_6a821_row0_col0, #T_6a821_row0_col5, #T_6a821_row0_col9, #T_6a821_row1_col0, #T_6a821_row1_col5, #T_6a821_row1_col6, #T_6a821_row1_col9, #T_6a821_row1_col10, #T_6a821_row2_col0, #T_6a821_row2_col5, #T_6a821_row2_col7, #T_6a821_row2_col9, #T_6a821_row2_col12, #T_6a821_row3_col0, #T_6a821_row3_col2, #T_6a821_row3_col3, #T_6a821_row3_col4, #T_6a821_row3_col5, #T_6a821_row3_col8, #T_6a821_row3_col9, #T_6a821_row3_col13, #T_6a821_row3_col14, #T_6a821_row4_col0, #T_6a821_row4_col5, #T_6a821_row4_col9, #T_6a821_row4_col11 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_6a821_row0_col2, #T_6a821_row0_col3, #T_6a821_row0_col4, #T_6a821_row0_col8, #T_6a821_row0_col12, #T_6a821_row0_col14, #T_6a821_row2_col13, #T_6a821_row3_col7, #T_6a821_row3_col11, #T_6a821_row4_col6, #T_6a821_row4_col10 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_6a821_row0_col6, #T_6a821_row4_col12 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# ...

# %%
#SHow the last 5 rows of the dataframe
DA_df.tail().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_4fc2b_row0_col0, #T_4fc2b_row0_col5, #T_4fc2b_row0_col6, #T_4fc2b_row0_col9, #T_4fc2b_row0_col10, #T_4fc2b_row1_col0, #T_4fc2b_row1_col5, #T_4fc2b_row2_col0, #T_4fc2b_row2_col5, #T_4fc2b_row2_col9, #T_4fc2b_row3_col0, #T_4fc2b_row3_col5, #T_4fc2b_row3_col9, #T_4fc2b_row4_col0, #T_4fc2b_row4_col2, #T_4fc2b_row4_col3, #T_4fc2b_row4_col4, #T_4fc2b_row4_col5, #T_4fc2b_row4_col7, #T_4fc2b_row4_col8, #T_4fc2b_row4_col9, #T_4fc2b_row4_col11, #T_4fc2b_row4_col12, #T_4fc2b_row4_col13, #T_4fc2b_row4_col14 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_4fc2b_row0_col2 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_4fc2b_row0_col3, #T_4fc2b_row0_col4 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_4fc2b_row0_col7 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# ...

# %%
# show different information such as:
# rows from RangeIndex, Data columns and then data type of each column
DA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
# Show the length of the dataframe
len(DA_df)
# Out:
# 940

# %%
# Show all of the columns
DA_df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
# Show total number of not a number values in the dataframe
DA_df.isna().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
# Show total number of null values in the dataframe
DA_df.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
# Get the value counts of each category 
DA_df["Id"].value_counts(ascending=True)
# Out:
# 4057192912     4
# 2347167796    18
# 8253242879    19
# 3372868164    20
# 7007744171    26
# 6775888955    26
# 6117666160    28
# 8792009665    29
# 6290855005    29
# 1644430081    30
# 5577150313    30
# 3977333714    30
# 1503960366    31
# 6962181067    31
# 8053475328    31
# 8378563200    31
# 8583815059    31
# 7086361926    31
# 5553957443    31
# 4445114986    31
# 4558609924    31
# 4388161847    31
# 4319703577    31
# 4020332650    31
# 2873212765    31
# 2320127002    31
# 2026352035    31
# 2022484408    31
# 1927972279    31
# 1844505072    31
# 1624580081    31
# 4702921684    31
# 8877689391    31
# Name: Id, dtype: int64

# %%
# Group the data for each category for its features maximum value
DA_df.groupby("Id").max()
# Out:
#            ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# Id
# 1503960366     5/9/2016       18134      12.210000        12.210000
# 1624580081     5/9/2016       36019      28.030001        28.030001
# 1644430081     5/9/2016       18213      13.240000        13.240000
# 1844505072     5/9/2016        8054       5.320000         5.320000
# 1927972279     5/9/2016        3790       2.620000         2.620000
# 2022484408     5/9/2016       18387      12.910000        12.910000
# 2026352035     5/9/2016       12357       7.710000         7.710000
# 2320127002     5/9/2016       10725       7.490000         7.490000
# 2347167796    4/29/2016       22244      15.080000        15.080000
# 2873212765     5/9/2016        9685       6.650000         6.650000
# 3372868164     5/1/2016        9715       6.630000         6.630000
# 3977333714     5/9/2016       16520      11.050000        11.050000
# 4020332650     5/9/2016       11728       8.430000         8.430000
# ...

# %%
# Show the total unique values of variables
DA_df.nunique()
# Out:
# Id                           33
# ActivityDate                 31
# TotalSteps                  842
# TotalDistance               615
# TrackerDistance             613
# LoggedActivitiesDistance     19
# VeryActiveDistance          333
# ModeratelyActiveDistance    211
# LightActiveDistance         491
# SedentaryActiveDistance       9
# VeryActiveMinutes           122
# FairlyActiveMinutes          81
# LightlyActiveMinutes        335
# SedentaryMinutes            549
# Calories                    734
# dtype: int64

# %% [markdown]
# ## **4. Process Data 🤖**
# ---
# Key Tasks:
#
# * Check the data for errors.
# * Transform the data to work with it effectively.
# * Document the cleaning process.
#
# From the above observation:
#
# * The dataframe has 15 columns and 940 rows.
# * There is no typo, NaN, and Null.
# * ActivityDate is wrongly classified as object dtype and has to be converted to datetime64 dtype.
# * There are 33 unique IDs, instead of 30 unique IDs that is the fitness tracker users as stated in the dataset description.
#
# The following operation needs to be done:
# * Changing the column "ActivityData" data-type to datetime64 and convert the format to yyyy-mm-dd.
# * Creating new column "DayOfTheWeek" by separating the date into day of the week for further analysis.
# * Creating new column "TotalMins" being the sum of "VeryActiveMinutes", "FairlyActiveMinutes", "LightlyActiveMinutes", and "SedentaryMinutes".
# * Creating new column "TotalHours" by converting new column in column "TotalMins" to number of hours.
# * Rearranging all of the columns.

# %%
# Changing column ActivityDate from object to datetime64
DA_df['ActivityDate'] = pd.to_datetime(DA_df['ActivityDate'], format="%m/%d/%Y")
DA_df['ActivityDate'].head()
# Out:
# 0   2016-04-12
# 1   2016-04-13
# 2   2016-04-14
# 3   2016-04-15
# 4   2016-04-16
# Name: ActivityDate, dtype: datetime64[ns]

# %%
# Creating new column "DayOfTheWeek" for the day of the week out of "ActivityDate"

DA_df["DayOfTheWeek"] = DA_df["ActivityDate"].dt.day_name()
DA_df["DayOfTheWeek"].head()
# Out:
# 0      Tuesday
# 1    Wednesday
# 2     Thursday
# 3       Friday
# 4     Saturday
# Name: DayOfTheWeek, dtype: object

# %%
# Creating new column "TotalMinutes" for the total minutes out of "VeryActiveMinutes", "FairlyActiveMinutes", "lightlyActiveMinutes", and "SedentaryMinutes"
DA_df["TotalMinutes"] = DA_df["VeryActiveMinutes"] + DA_df["FairlyActiveMinutes"] + DA_df["LightlyActiveMinutes"] + DA_df["SedentaryMinutes"]
DA_df["TotalMinutes"].head()
# Out:
# 0    1094
# 1    1033
# 2    1440
# 3     998
# 4    1040
# Name: TotalMinutes, dtype: int64

# %%
# Creating new column for Total Hour 
DA_df["TotalHours"] = round(DA_df["TotalMinutes"] / 60)
DA_df["TotalHours"].head()
# Out:
# 0    18.0
# 1    17.0
# 2    24.0
# 3    17.0
# 4    17.0
# Name: TotalHours, dtype: float64

# %%
# Rearranging the columns of the dataframe
new_column = ['Id', 'ActivityDate', 'DayOfTheWeek', 'TotalSteps', 'TotalDistance', 
              'TrackerDistance', 'LoggedActivitiesDistance', 'VeryActiveDistance', 
              'ModeratelyActiveDistance', 'LightActiveDistance', 'SedentaryActiveDistance', 
              'TotalHours', 'TotalMinutes', 'VeryActiveMinutes', 'FairlyActiveMinutes', 
              'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']

DA_df = DA_df.reindex(columns = new_column)

DA_df.head(10).style.background_gradient(cmap='magma')
# Out:
# <style type="text/css">
# #T_e395f_row0_col0, #T_e395f_row0_col6, #T_e395f_row0_col10, #T_e395f_row1_col0, #T_e395f_row1_col6, #T_e395f_row1_col10, #T_e395f_row2_col0, #T_e395f_row2_col6, #T_e395f_row2_col10, #T_e395f_row3_col0, #T_e395f_row3_col4, #T_e395f_row3_col5, #T_e395f_row3_col6, #T_e395f_row3_col10, #T_e395f_row4_col0, #T_e395f_row4_col6, #T_e395f_row4_col10, #T_e395f_row5_col0, #T_e395f_row5_col3, #T_e395f_row5_col6, #T_e395f_row5_col9, #T_e395f_row5_col10, #T_e395f_row5_col11, #T_e395f_row5_col12, #T_e395f_row5_col15, #T_e395f_row5_col16, #T_e395f_row5_col17, #T_e395f_row6_col0, #T_e395f_row6_col6, #T_e395f_row6_col10, #T_e395f_row7_col0, #T_e395f_row7_col6, #T_e395f_row7_col10, #T_e395f_row8_col0, #T_e395f_row8_col6, #T_e395f_row8_col10, #T_e395f_row9_col0, #T_e395f_row9_col6, #T_e395f_row9_col7, #T_e395f_row9_col8, #T_e395f_row9_col10, #T_e395f_row9_col13, #T_e395f_row9_col14 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_e395f_row0_col3 {
# ...

# %%
# Rechecking to make sure that the dataframe has been correctly prepared and processed
DA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    datetime64[ns]
#  2   DayOfTheWeek              940 non-null    object
#  3   TotalSteps                940 non-null    int64
#  4   TotalDistance             940 non-null    float64
#  5   TrackerDistance           940 non-null    float64
#  6   LoggedActivitiesDistance  940 non-null    float64
#  7   VeryActiveDistance        940 non-null    float64
#  8   ModeratelyActiveDistance  940 non-null    float64
#  9   LightActiveDistance       940 non-null    float64
#  10  SedentaryActiveDistance   940 non-null    float64
#  11  TotalHours                940 non-null    float64
#  12  TotalMinutes              940 non-null    int64
# ...

# %% [markdown]
# # **Analyze Phase 🔬**
# ***
#
# Now that the dataframe is stored appropriately and has been prepared for analysis, continue to the next step which is analyze phase.
#
# Key Tasks:
# * Aggregate your data so it’s useful and accessible.
# * Organize and format the data.
# * Perform calculations.
# * Identify trends and relationships.
#
# Let's use function "describe()" to show the basic statistic of the dataframe. This function is really helpful for understanging and idetifying trends and relationship.

# %%
# SHowing the basic statistic of the data
DA_df.describe().style.background_gradient(cmap='cividis')
# Out:
# <style type="text/css">
# #T_f48fd_row0_col0, #T_f48fd_row1_col4, #T_f48fd_row1_col5, #T_f48fd_row1_col6, #T_f48fd_row1_col7, #T_f48fd_row1_col8, #T_f48fd_row2_col4, #T_f48fd_row2_col5, #T_f48fd_row2_col6, #T_f48fd_row2_col7, #T_f48fd_row2_col8, #T_f48fd_row3_col1, #T_f48fd_row3_col2, #T_f48fd_row3_col3, #T_f48fd_row3_col4, #T_f48fd_row3_col5, #T_f48fd_row3_col6, #T_f48fd_row3_col7, #T_f48fd_row3_col8, #T_f48fd_row3_col9, #T_f48fd_row3_col10, #T_f48fd_row3_col11, #T_f48fd_row3_col12, #T_f48fd_row3_col13, #T_f48fd_row3_col14, #T_f48fd_row3_col15, #T_f48fd_row4_col2, #T_f48fd_row4_col3, #T_f48fd_row4_col4, #T_f48fd_row4_col5, #T_f48fd_row4_col6, #T_f48fd_row4_col7, #T_f48fd_row4_col8, #T_f48fd_row4_col11, #T_f48fd_row4_col12, #T_f48fd_row5_col4, #T_f48fd_row5_col5, #T_f48fd_row5_col6, #T_f48fd_row5_col7, #T_f48fd_row5_col8, #T_f48fd_row6_col4, #T_f48fd_row6_col5, #T_f48fd_row6_col6, #T_f48fd_row6_col8, #T_f48fd_row7_col8 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# The key findings based on the data:
# * The average steps in total that the users took is around 7637 steps
# * The average distance is around 5.5 kilometers.
# * The average calories burnt daily is around 2303 calories.
# * Most of the time that all of the users spent is when they were in "sedentary" or inactive which has an average of 991 minutes. The least time in average that the users spent is when they were in "fairly active".
# * The total average minutes tracked of the users is around 1218 minutes or around 20.3 hours.

# %% [markdown]
# # **Share Phase 🎉**
# ***
#
# Once the analysis has been completed, now it is time to create data visualizations. The visualizations should clearly communicate the high-level insights and recommendations.
#
# Key tasks
# * Determine the best way to share findings.
# * Create effective data visualizations.
# * Present the findings.
# * Ensure the work is accessible.
#
# ## **1. Plotting a histogram to show the frequency users using FitBit app in a week 🗓️**
# ---
# A histogram is a graphical representation of the distribution of numerical data.

# %%
plt.figure(figsize=(10,5))
plt.hist(DA_df.DayOfTheWeek, bins = 7, width = 0.7, color = "coral", ec = "black")

# Adding title, x and y axis labels, and grid
plt.title("The Frequency of Users Logging Activity in a Week", fontsize=16)
plt.xlabel("Day of the week")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# The frequency of FitBit app usage in terms of days of the week is shown on histogram above. The bar is consistently decreasing from Tuesday until Monday. It is assumed that the users were not exercising enough during the weekends compared to the weekdays or the FitBit users did not use the app to track their activities.
#
# ## **2. Plotting a Pie Charts to represent the percentage of users activity in minutes ⏲️**
# ---
# A pie charts is a circle-shaped graph in which a circle is divided into sectors, each representing a percentage of the whole.

# %%
# Calculating the total of each columns
VeryActive = DA_df["VeryActiveMinutes"].sum()
FairlyActive = DA_df["FairlyActiveMinutes"].sum()
LightlyActive = DA_df["LightlyActiveMinutes"].sum()
Sedentary = DA_df["SedentaryMinutes"].sum()

# Plotting a pie charts
segments = [VeryActive, FairlyActive, LightlyActive, Sedentary]
labels = ["Very Active", "Fairly Active", "Lightly Active", "Sedentary"]
colors = ["cyan", "yellow", "magenta", "green"]
explode = [0.1, 0.1, 0.1, 0.2]
plt.pie(segments, labels = labels, colors = colors, startangle = 180,
        wedgeprops = {"edgecolor": "black"}, shadow = True,
        explode = explode, autopct = "%1.1f%%")
plt.title("Percentage of Users' Activities in Minutes")
plt.legend(title = "Activities", loc = "lower right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Key findings from the pie charts above:
# * The pie charts indicates that users were using the FitBit app to log for their daily activities.
# * Sedentary state of users make up the most (81.33%) of other activities in minutes.
# * The pie charts could indicate that the users did not use the app as intended such as working out, running, fitness, etc. Despite the fact that the app intention is to encourage fitness of the users.
#
# ## **3. Plotting a scatter plot to show correlations between two variables 📊**
# ---
# A scatterplot depicts the magnitude, direction, and shape of a relationship between two quantitative variables.

# %%
# Initialise the subplot function using number of rows and columns
fig, axis = plt.subplots(1, 2, figsize=(15, 8))

m1, b1 = np.polyfit(DA_df.TotalSteps, DA_df.Calories, 1)
mean_calories = DA_df.Calories.mean()
mean_steps = DA_df.TotalSteps.mean()

m2, b2 = np.polyfit(DA_df.TotalDistance, DA_df.Calories, 1)
mean_calories = DA_df.Calories.mean()
mean_distance = DA_df.TotalDistance.mean()

# Plotting a scatter plot
axis[0].scatter(DA_df.TotalSteps, DA_df.Calories, alpha = 0.8, c = DA_df.Calories, cmap = "hot")
axis[0].plot(DA_df.TotalSteps, m1 * DA_df.TotalSteps + b1, '-', color='brown')

# Adding annotations and visuals
# axis[0].colorbar(orientation = "vertical")
axis[0].axvline(mean_steps, color = "Green", label = "Mean Total Steps")
axis[0].axhline(mean_calories, color = "Blue", label = "Mean Calories")
axis[0].set_xlabel("Total Steps")
axis[0].set_ylabel("Calories burned")
axis[0].set_title("Correlation Between the Total Steps and Calories Burned")
axis[0].grid(True)
axis[0].legend(loc = "lower right")

# Plotting a scatter plot
axis[1].scatter(DA_df.TotalDistance, DA_df.Calories, alpha = 0.8, c = DA_df.Calories, cmap = "hot")
axis[1].plot(DA_df.TotalDistance, m2 * DA_df.TotalDistance + b2, '-', color='brown')

# Adding annotations and visuals
axis[1].axvline(mean_distance, color = "Green", label = "Mean Total Distance")
axis[1].axhline(mean_calories, color = "Blue", label = "Mean Calories")
axis[1].set_xlabel("Total Distance")
axis[1].set_ylabel("Calories burned")
axis[1].set_title("Correlation Between the Total Distance and Calories Burned")
axis[1].grid(True)
axis[1].legend(loc = "lower right")
#plt.colorbar(orientation = "vertical")
plt.show()

# %% [markdown]
# Key findings from the scatter plots above:
# * There is a positive correlation as shown in a brown line in both graphs between the total steps and the calories burned and between total distance and calories burned.
# * There are outliers in this data which can be caused by errors in data collection, miscalculations, data contamination, human error, etc.

# %%
m3, b3 = np.polyfit(DA_df.TotalHours, DA_df.Calories, 1)
mean_calories = DA_df.Calories.mean()
mean_sedentary = DA_df.SedentaryMinutes.mean()/60.0
mean_hours = DA_df.TotalHours.mean()

# Plotting a scatter plot
plt.figure(figsize=(8,6)) # Specify size of the chart
plt.scatter(DA_df.TotalHours, DA_df.Calories, alpha = 0.8, c = DA_df.Calories, cmap = "hot")
plt.plot(DA_df.TotalHours, m3 * DA_df.TotalHours + b3, '-', color='brown')

# Adding annotations and visuals
plt.colorbar(orientation = "vertical")
plt.axhline(mean_calories, color = "Blue", label = "Mean Calories")
plt.axvline(mean_sedentary, color = "Green", label = "Mean Sedentary")
plt.axvline(mean_hours, color = "Purple", label = "Mean Hours")
plt.xlabel("Hours Logged")
plt.ylabel("Calories Burned")
plt.title("The Correlation Between Calories Burned for Every Hour Logged")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Key findings from the scatter plot above:
# * A weak positive correlation as shown in a brown line whereas the increase of the hours logged does not translate to more calories being burned. That is largely due to the average sedentary hours (green line) plotted at the 16 to 17 hours range.
# * Some outliers in the data

# %% [markdown]
# # **Act Phase ✨**
# ---
# After creating the visualizations of the data, now act on the key findings. Prepare the deliverables that have been asked to create, including the high-level recommendations based on analysis.
#
# * **What are some trends in smart device usage?**
#
# The FitBit app was used by the majority of users (81.3%) to track sedentary activities rather than their fitness habits. Users prefer to use the app more during the weekdays compared to the weekends based on the data. It is assumed that that FitBit users did not use the app all the time to track their activities.
#
# * **How could these trends apply to Bellabeat customers?**
#
# Both companies create products that aim to provide women with health, habit, and fitness data while also encouraging them to understand their current habits and make healthy choices. Since, we do not have the actual data from BellaBeat customer data, the third party data was used in this case. Thus, these common health and fitness data trends can be applied also in this case to the Bellabeat users.
#
# * **How could these trends help influence Bellabeat marketing strategy?**
#
# The Bellabeat marketing team can encourage users by educating and equipping users with knowledge about fitness benefits, recommending different types of exercise (for example, a quick and simple routine exercise during the weekdays), and providing calories intake and burn rate information to boost the users interest to use the Bellabeat app. On weekends, the Bellabeat app may also send out reminders by showing notifications to encourage users to exercise.
